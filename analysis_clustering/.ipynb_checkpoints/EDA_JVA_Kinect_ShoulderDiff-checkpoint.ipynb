# %% [markdown]
# ## KMeans Clustering -- EDA, JVA & Kinect(HeadDiff)

# %% [markdown]
# The clustering analysis below explores how motor sensors used in the MMLA study predict qualitative, collaborative outcomes. Measures used are as follows:
# 1. EDA: Directional Agreement, Signal Matching, Pearsons' Correlations, Instantaneous Directional Matching
# 2. JVA: number of jva100 counts per second
# 3. ShoulderDiff: horizontal differences in shoulder orientation
#
# Clustering analysis was performed by combining each EDA measure with JVA and Kinect, the resulting analyses were:
#
# 1. DA+JVA+ShoulderDiff
# 2. SM+JVA+ShoulderDiff
# 3. PC+JVA+ShoulderDiff
# 4. IDM+JVA+ShoulderDiff
#
# _K in [3,5] for each combination is explored below._

# %%
#import packages for clustering
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
import sys
sys.path.insert(0, '../src/')
import cluster
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
sessions = pd.read_csv('../data_master/sessions.csv') #read sessions data
dependent = ['Sustaining Mutual Understanding ', 'Dialogue Management',
             'Information Pooling', 'Reaching Consensus', 'Task Division',
             'Time Managment', 'Technical Coordination', 'Reciprocal Interaction',
             'Individual Task Orientation', 'Collaboration', 'Task Performance',
             'Task Understanding', 'Improvement Over Time', 'Code quality',
             'Learning']

# %%
dfMaster = pd.read_csv('../data_master/EDA_JVA_Kinect_MasterScaled.csv', index_col='Unnamed: 0')
dfMaster.head()
# Out:
#    index  session  second        DA        PC       IDM        SM  jva100  \
# 0      0        2       1  0.233333 -0.447563  0.177397  0.208709    24.0
# 1      1        2       2  0.232708 -0.445837  0.177548  0.207804     7.0
# 2      2        2       3  0.233125 -0.442000  0.177468  0.206289    18.0
# 3      3        2       4  0.234583 -0.439776  0.176532  0.205172    23.0
# 4      4        2       5  0.234375 -0.438995  0.175948  0.204015     6.0
#
#    moveDiff  headDiff  shoulderDiff  DA_scaled  PC_scaled  IDM_scaled  \
# 0  1.941329  0.047057      0.658437  -0.408346  -1.253811   -0.669944
# 1  2.013969  0.040868      0.654975  -0.416471  -1.249036   -0.669415
# 2  1.825878  0.048828      0.642805  -0.411054  -1.238426   -0.669694
# 3  1.675585  0.037022      0.648898  -0.392095  -1.232274   -0.672974
# 4  1.967405  0.042931      0.646596  -0.394804  -1.230112   -0.675019
#
#    SM_scaled  jva100_scaled  moveDiff_scaled  headDiff_scaled  \
# 0  -1.363551       1.713567        -0.346045        -0.454587
# 1  -1.365111      -0.173196        -0.314421        -0.516680
# 2  -1.367720       1.047651        -0.396306        -0.436817
# 3  -1.369643       1.602581        -0.461736        -0.555270
# 4  -1.371636      -0.284182        -0.334693        -0.495984
#
#    shoulderDiff_scaled
# 0             0.640038
# 1             0.612066
# 2             0.513720
# 3             0.562954
# 4             0.544357

# %% [markdown]
# **Optimal K by Distortion Rate**

# %%
#find optimal number of clustering for KMeans
distortionPC = list() #cache list for distortion value
for n in range(1,11): #fit number of clusters in the range of 1 to 10
    kmeans_pc = KMeans(n_clusters=n, random_state=11)
    kmeans_pc.fit(dfMaster.loc[:, ['PC_scaled','jva100_scaled','shoulderDiff_scaled']]) 
    distortionPC.append(kmeans_pc.inertia_) #append distortion value to list
print('PC completed')

distortionDA = list()
for n in range(1,11):
    kmeans_da = KMeans(n_clusters=n, random_state=11)
    kmeans_da.fit(dfMaster.loc[:, ['DA_scaled','jva100_scaled','shoulderDiff_scaled']])
    distortionDA.append(kmeans_da.inertia_)
print('DA completed')

distortionSM = list()
for n in range(1,11):
    kmeans_sm = KMeans(n_clusters=n, random_state=11)
    kmeans_sm.fit(dfMaster.loc[:, ['SM_scaled','jva100_scaled','shoulderDiff_scaled']])
    distortionSM.append(kmeans_sm.inertia_)
print('SM completed')


distortionIDM = list()
for n in range(1,11):
    kmeans_idm = KMeans(n_clusters=n, random_state=11)
    kmeans_idm.fit(dfMaster.loc[:, ['IDM_scaled','jva100_scaled','shoulderDiff_scaled']])
    distortionIDM.append(kmeans_idm.inertia_)
print('IDM completed')


#plot elbow curves 
fig = plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), distortionPC, c = 'b', label = 'PC+JVA+ShoulderDiff')
plt.plot(range(1, 11), distortionDA, c = 'g', label = 'DA+JVA+ShoulderDiff')
plt.plot(range(1, 11), distortionSM, c = 'r', label = 'SM+JVA+ShoulderDiff')
plt.plot(range(1, 11), distortionIDM, c = 'y', label = 'IDM+JVA+ShoulderDiff')
plt.xlabel('Number of Clusters')
plt.ylabel('Distortion')
plt.legend()
plt.grid(True)
plt.title('Elbow curve')
plt.show()
# Out:
# PC completed
# DA completed
# SM completed
# IDM completed

# %% [markdown]
# **PC+JVA+Kinect**

# %%
#cluster by K=3 , K=4 and K = 5
dfMaster_pc3, centroids_pc3 = cluster.makeCluster(dfMaster, 3, 11, ['PC_scaled','jva100_scaled','shoulderDiff_scaled'])
dfMaster_pc4, centroids_pc4 = cluster.makeCluster(dfMaster, 4, 11, ['PC_scaled','jva100_scaled','shoulderDiff_scaled'])
dfMaster_pc5, centroids_pc5 = cluster.makeCluster(dfMaster, 5, 11, ['PC_scaled','jva100_scaled','shoulderDiff_scaled'])

# %%
dfMaster_pc4.to_csv('../data_visualization/PC_JVA_ShoulderDiff_4.csv')

# %% [markdown]
# ----
# K = 3

# %%
cluster.visualizeCluster(dfMaster_pc3, 3, ['PC_scaled','jva100_scaled','shoulderDiff_scaled'], ['PC','jva100','shoulderDiff'] )

# %%
timeCluster_pc3 = cluster.timeCluster(dfMaster_pc3, 3)
sessions_pc3 = sessions.merge(timeCluster_pc3, on = 'Session', how = 'outer') #merge data frames for correlation
time_pc3 = ['timeCluster1','timeCluster2','timeCluster3']

correlations_pc3 = sessions_pc3.corr()
ax = sns.heatmap(correlations_pc3.loc[dependent][time_pc3], annot=True)

# %%
pvalues_pc3 = cluster.calculate_pvalues(sessions_pc3).astype(float)
ax = sns.heatmap(pvalues_pc3.loc[dependent][time_pc3], annot=True)

# %% [markdown]
# Significant correlations: 1) time spent in cluster 3 (highest jva) and sustaining mutual understanding ( p = 0.018).

# %% [markdown]
# ----
# K = 4

# %%
cluster.visualizeCluster(dfMaster_pc4, 4, ['PC_scaled','jva100_scaled','shoulderDiff_scaled'], ['PC','jva100','shoulderDiff'] )

# %%
timeCluster_pc4 = cluster.timeCluster(dfMaster_pc4, 4)
sessions_pc4 = sessions.merge(timeCluster_pc4, on = 'Session', how = 'outer') #merge data frames for correlation
time_pc4 = ['timeCluster1','timeCluster2','timeCluster3','timeCluster4']

correlations_pc4 = sessions_pc4.corr()
ax = sns.heatmap(correlations_pc4.loc[dependent][time_pc4], annot=True)

# %%
pvalues_pc4 = cluster.calculate_pvalues(sessions_pc4).astype(float)
ax = sns.heatmap(pvalues_pc4.loc[dependent][time_pc4], annot=True)

# %% [markdown]
# Significant correlations: 1) time spent in cluster 1 (Highest jva) and sustaining mutual understanding (p = 0.022)2) time spent in cluster 2 (Highest PC) and sustaining mutual understanding (p = 0.039).

# %% [markdown]
# ----
# K = 5

# %%
cluster.visualizeCluster(dfMaster_pc5, 5, ['PC_scaled','jva100_scaled','shoulderDiff_scaled'], ['PC','jva100','shoulderDiff'] )

# %%
timeCluster_pc5 = cluster.timeCluster(dfMaster_pc5, 5)
sessions_pc5 = sessions.merge(timeCluster_pc5, on = 'Session', how = 'outer') #merge data frames for correlation
time_pc5 = ['timeCluster1','timeCluster2','timeCluster3','timeCluster4','timeCluster4']

correlations_pc5 = sessions_pc5.corr()
ax = sns.heatmap(correlations_pc5.loc[dependent][time_pc5], annot=True)

# %%
pvalues_pc5 = cluster.calculate_pvalues(sessions_pc5).astype(float)
ax = sns.heatmap(pvalues_pc5.loc[dependent][time_pc5], annot=True)

# %% [markdown]
# Significant correlations: 1) time spent in cluster 2 and sustaining mutual understanding (p = 0.024), dialogue management (p = 0.042).

# %% [markdown]
# **SM+JVA+Kinect**

# %%
#cluster by K=3 , K=4 and K = 5
dfMaster_sm3, centroids_sm3 = cluster.makeCluster(dfMaster, 3, 11, ['SM_scaled','jva100_scaled','shoulderDiff_scaled'])
dfMaster_sm4, centroids_sm4 = cluster.makeCluster(dfMaster, 4, 11, ['SM_scaled','jva100_scaled','shoulderDiff_scaled'])
dfMaster_sm5, centroids_sm5 = cluster.makeCluster(dfMaster, 5, 11, ['SM_scaled','jva100_scaled','shoulderDiff_scaled'])

# %%
dfMaster_sm4.to_csv('../data_visualization/SM_JVA_ShoulderDiff_4.csv')

# %% [markdown]
# ----
# K = 3

# %%
cluster.visualizeCluster(dfMaster_sm3, 3, ['SM_scaled','jva100_scaled','shoulderDiff_scaled'], ['SM','jva100','shoulderDiff'] )

# %%
timeCluster_sm3 = cluster.timeCluster(dfMaster_sm3, 3)
sessions_sm3 = sessions.merge(timeCluster_sm3, on = 'Session', how = 'outer') #merge data frames for correlation
time_sm3 = ['timeCluster1','timeCluster2','timeCluster3']

correlations_sm3 = sessions_sm3.corr()
ax = sns.heatmap(correlations_sm3.loc[dependent][time_sm3], annot=True)

# %%
pvalues_sm3 = cluster.calculate_pvalues(sessions_sm3).astype(float)
ax = sns.heatmap(pvalues_sm3.loc[dependent][time_sm3], annot=True)

# %% [markdown]
# SIgnificant correlations: 1) time spent in cluster 1 (highest jva) and sustaining mutual understanding (p = 0.029), 2) time spent in cluster 2 (highest SM, most shoulder diff) and sustaining mutual understanding (p = 0.023), dialogue management (p = 0.004), task performance (p = 0.035), learning (p = 0.003).

# %% [markdown]
# ----
# K = 4

# %%
cluster.visualizeCluster(dfMaster_sm4, 4, ['SM_scaled','jva100_scaled','shoulderDiff_scaled'], ['SM','jva100','shoulderDiff'] )

# %%
timeCluster_sm4 = cluster.timeCluster(dfMaster_sm4, 4)
sessions_sm4 = sessions.merge(timeCluster_sm4, on = 'Session', how = 'outer') #merge data frames for correlation
time_sm4 = ['timeCluster1','timeCluster2','timeCluster3','timeCluster4']

correlations_sm4 = sessions_sm4.corr()
ax = sns.heatmap(correlations_sm4.loc[dependent][time_sm4], annot=True)

# %%
pvalues_sm4 = cluster.calculate_pvalues(sessions_sm4).astype(float)
ax = sns.heatmap(pvalues_sm4.loc[dependent][time_sm4], annot=True)

# %% [markdown]
# Significant correlations: 1) time spent in cluster 2 (highest jva) and sustaining mutual understanding (p = 0.036), 2) time spent in cluster 3 (highest SM) and reaching consensus( p = 0.033), task performance (p =0.017), improvement over time (p < 0.001), 3) time spent in cluster 4 (most shoulderdiff) and sustaining mutual understanding (p = 0.028).

# %% [markdown]
# ----
# K = 5

# %%
cluster.visualizeCluster(dfMaster_sm5, 5, ['SM_scaled','jva100_scaled','shoulderDiff_scaled'], ['SM','jva100','shoulderDiff'] )

# %%
timeCluster_sm5 = cluster.timeCluster(dfMaster_sm5, 5)
sessions_sm5 = sessions.merge(timeCluster_sm5, on = 'Session', how = 'outer') #merge data frames for correlation
time_sm5 = ['timeCluster1','timeCluster2','timeCluster3','timeCluster4','timeCluster5']

correlations_sm5 = sessions_sm5.corr()
ax = sns.heatmap(correlations_sm5.loc[dependent][time_sm5], annot=True)

# %%
pvalues_sm5 = cluster.calculate_pvalues(sessions_sm5).astype(float)
ax = sns.heatmap(pvalues_sm5.loc[dependent][time_sm5], annot=True)

# %% [markdown]
# Significant correlations: 1) time spent in cluster 2 (most shoulder diff) and sustaining mutual understanding (p = 0.003), dialogue management (p = 0.013), information pooling (p = 0.035),collaboration (p = 0.035), learning (p = 0.037) 2) time spent in clutser 3 (highest jva) and sustaining mutual understanding (p = 0.038), 3) time spent in cluster 4 (highest SM) and improvement over time (p < 0.001).

# %% [markdown]
# **DA+JVA+Kinect**

# %%
#cluster by K=3 , K=4 and K = 5
dfMaster_da3, centroids_da3 = cluster.makeCluster(dfMaster, 3, 11, ['DA_scaled','jva100_scaled','shoulderDiff_scaled'])
dfMaster_da4, centroids_da4 = cluster.makeCluster(dfMaster, 4, 11, ['DA_scaled','jva100_scaled','shoulderDiff_scaled'])
dfMaster_da5, centroids_da5 = cluster.makeCluster(dfMaster, 5, 11, ['DA_scaled','jva100_scaled','shoulderDiff_scaled'])

# %%
dfMaster_da4.to_csv('../data_visualization/DA_JVA_ShoulderDiff_4.csv')

# %% [markdown]
# ----
# K = 3

# %%
cluster.visualizeCluster(dfMaster_da3, 3, ['DA_scaled','jva100_scaled','shoulderDiff_scaled'], ['DA','jva100','shoulderDiff'] )

# %%
timeCluster_da3 = cluster.timeCluster(dfMaster_da3, 3)
sessions_da3 = sessions.merge(timeCluster_da3, on = 'Session', how = 'outer') #merge data frames for correlation
time_da3 = ['timeCluster1','timeCluster2','timeCluster3']

correlations_da3 = sessions_da3.corr()
ax = sns.heatmap(correlations_da3.loc[dependent][time_da3], annot=True)

# %%
pvalues_da3 = cluster.calculate_pvalues(sessions_da3).astype(float)
ax = sns.heatmap(pvalues_da3.loc[dependent][time_da3], annot=True)

# %% [markdown]
# There is one significant correlation between time spent in cluster 3 and task division (p = 0.044)

# %% [markdown]
# ----
# K = 4

# %%
cluster.visualizeCluster(dfMaster_da4, 4, ['DA_scaled','jva100_scaled','shoulderDiff_scaled'], ['DA','jva100','shoulderDiff'] )

# %%
timeCluster_da4 = cluster.timeCluster(dfMaster_da4, 4)
sessions_da4 = sessions.merge(timeCluster_da4, on = 'Session', how = 'outer') #merge data frames for correlation
time_da4 = ['timeCluster1','timeCluster2','timeCluster3','timeCluster4']

correlations_da4 = sessions_da4.corr()
ax = sns.heatmap(correlations_da4.loc[dependent][time_da4], annot=True)

# %%
pvalues_da4 = cluster.calculate_pvalues(sessions_da4).astype(float)
ax = sns.heatmap(pvalues_da4.loc[dependent][time_da4], annot=True)

# %% [markdown]
# Significant correlations: 1) time spent in cluster 3 (highest DA) and reciprocal interaction (p = 0.023), 2) time spent in cluster 4 (most shoulder diff) and task division (p = 0.018).

# %% [markdown]
# ----
# K = 5

# %%
cluster.visualizeCluster(dfMaster_da5, 5, ['DA_scaled','jva100_scaled','shoulderDiff_scaled'], ['DA','jva100','shoulderDiff'] )

# %%
timeCluster_da5 = cluster.timeCluster(dfMaster_da5, 5)
sessions_da5 = sessions.merge(timeCluster_da5, on = 'Session', how = 'outer') #merge data frames for correlation
time_da5 = ['timeCluster1','timeCluster2','timeCluster3','timeCluster4','timeCluster5']

correlations_da5 = sessions_da5.corr()
ax = sns.heatmap(correlations_da5.loc[dependent][time_da5], annot=True)

# %%
pvalues_da5 = cluster.calculate_pvalues(sessions_da5).astype(float)
ax = sns.heatmap(pvalues_da5.loc[dependent][time_da5], annot=True)

# %% [markdown]
# Significant correlations: 1) time spent in cluster 2 and dialogue management (p = 0.043), reciprocal interaction (p = 0.008), collaboration (p = 0.040), 2) time spent in cluster 4 and dialogue management (p = 0.032), task division (p = 0.032), reciprocal interaction (p = 0.033), individual task orientation (p = 0.026), collaboration (p = 0.01), learning (p = 0.022), 3) time spent in cluster 5 and sustaining mutual understanding (p = 0.042), task division (p = 0.019).
#
# Cluster 2: Highest DA
#
# Cluster 4: Least shoulder diff
#
# Cluster 5: Most shoulder diff

# %% [markdown]
# **IDM+JVA+Kinect**

# %%
#cluster by K=3 , K=4 and K = 5
dfMaster_idm3, centroids_idm3 = cluster.makeCluster(dfMaster, 3, 11, ['IDM_scaled','jva100_scaled','shoulderDiff_scaled'])
dfMaster_idm4, centroids_idm4 = cluster.makeCluster(dfMaster, 4, 11, ['IDM_scaled','jva100_scaled','shoulderDiff_scaled'])
dfMaster_idm5, centroids_idm5 = cluster.makeCluster(dfMaster, 5, 11, ['IDM_scaled','jva100_scaled','shoulderDiff_scaled'])

# %%
dfMaster_idm4.to_csv('../data_visualization/IDM_JVA_ShoulderDiff_4.csv')

# %% [markdown]
# ----
# K = 3

# %%
cluster.visualizeCluster(dfMaster_idm3, 3,['IDM_scaled','jva100_scaled','shoulderDiff_scaled'],['IDM','jva100','shoulderDiff'] )

# %%
timeCluster_idm3 = cluster.timeCluster(dfMaster_idm3, 3)
sessions_idm3 = sessions.merge(timeCluster_idm3, on = 'Session', how = 'outer') #merge data frames for correlation
time_idm3 = ['timeCluster1','timeCluster2','timeCluster3']

correlations_idm3 = sessions_idm3.corr()
ax = sns.heatmap(correlations_idm3.loc[dependent][time_idm3], annot=True)

# %%
pvalues_idm3 = cluster.calculate_pvalues(sessions_idm3).astype(float)
ax = sns.heatmap(pvalues_idm3.loc[dependent][time_idm3], annot=True)

# %% [markdown]
# Significant correlation between time spent in cluster 3 and sustaining mutual understanding (p = 0.019)

# %% [markdown]
# ----
# K = 4

# %%
cluster.visualizeCluster(dfMaster_idm4, 4,['IDM_scaled','jva100_scaled','shoulderDiff_scaled'],['IDM','jva100','shoulderDiff'] )

# %%
timeCluster_idm4 = cluster.timeCluster(dfMaster_idm4, 4)
sessions_idm4 = sessions.merge(timeCluster_idm4, on = 'Session', how = 'outer') #merge data frames for correlation
time_idm4 = ['timeCluster1','timeCluster2','timeCluster3','timeCluster4']

correlations_idm4 = sessions_idm4.corr()
ax = sns.heatmap(correlations_idm4.loc[dependent][time_idm4], annot=True)

# %%
pvalues_idm4 = cluster.calculate_pvalues(sessions_idm4).astype(float)
ax = sns.heatmap(pvalues_idm4.loc[dependent][time_idm4], annot=True)

# %% [markdown]
# Significant correlations between 1) time spent in cluster 1 and sustaining mutual understanding (p = 0.025).

# %% [markdown]
# ----
# K = 5

# %%
cluster.visualizeCluster(dfMaster_idm5, 5,['IDM_scaled','jva100_scaled','shoulderDiff_scaled'],['IDM','jva100','shoulderDiff'] )

# %%
timeCluster_idm5 = cluster.timeCluster(dfMaster_idm5, 5)
sessions_idm5 = sessions.merge(timeCluster_idm5, on = 'Session', how = 'outer') #merge data frames for correlation
time_idm5 = ['timeCluster1','timeCluster2','timeCluster3','timeCluster4','timeCluster5']

correlations_idm5 = sessions_idm5.corr()
ax = sns.heatmap(correlations_idm5.loc[dependent][time_idm5], annot=True)

# %%
pvalues_idm5 = cluster.calculate_pvalues(sessions_idm5).astype(float)
ax = sns.heatmap(pvalues_idm5.loc[dependent][time_idm5], annot=True)
